# %% [markdown]
# ### 1、please import pandas

# %%
import pandas as pd

# %% [markdown]
# ### 2、please read the Breast_cancer_data_for_ML.csv file and saved as DataFrame and name it as 'data'.
# прочтите файл и назовите его "данные

# %%
# загрузим набор данных в виде фрейма данных и рассмотрим, какие функции предоставляются вместе с их типами данных.
# индексом укажем столбец (id)
df = pd.read_csv(r'Breast_cancer_data_for_ML.csv',index_col = 'id')
df.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %% [markdown]
#     "Диагностическая база данных по раку молочной железы Висконсина" - это общедоступный набор данных из репозитория машинного обучения UCI. Набор данных содержит информацию об особенностях опухоли, которые вычисляются на основе оцифрованного изображения аспирата тонкой иглы (FNA) массы молочной железы.
#     Для каждого наблюдения существует 10 признаков, которые описывают размер опухоли, плотность, текстуру, симметрию и другие характеристики ядер клеток, присутствующих на изображении. Среднее значение, стандартная ошибка и "наихудшее" среднее значение (среднее из трех наибольших значений) этих признаков были вычислены для каждого изображения, в результате чего было получено 30 признаков. Категориальный целевой признак указывает на тип опухоли.

# %%
#посмотрим на состояние фрейма, убедимся в целостности данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569 entries, 842302 to 92751
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# Как видно, отсутствующих значений нет, за исключением последнего столбца.(31  /Unnamed: 32  /0 non-null  /float64)

# %%
# преобразуем целевой объект 'diagnosis' в категориальную функцию:
df['diagnosis'] = df['diagnosis'].astype('category')

# %% [markdown]
# ### 3、please drop the 'Unnamed: 32' column
# пожалуйста, удалите колонку 'Unnamed: 32'

# %%
df = df.drop(columns=['Unnamed: 32']) #удаление по группе столбцов, в нашем случае (Unnamed: 32)
df.sample(5) #случайные строки
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 911654           B        14.20         20.53           92.41      618.4
# 8953902          M        16.27         20.71          106.90      813.7
# 90524101         M        17.99         20.66          117.80      991.7
# 9010258          B        12.56         19.07           81.92      485.8
# 866083           M        13.61         24.69           87.76      572.6
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 911654            0.08931           0.11080         0.05063
# 8953902           0.11690           0.13190         0.14780
# 90524101          0.10360           0.13040         0.12010
# 9010258           0.08760           0.10380         0.10300
# 866083            0.09258           0.07862         0.05285
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %%
#df.describe().T #посмотрим на общую статистику. включая среднее значение, std, медиану, процентили и диапазон.

# %% [markdown]
# ### 4、please to use 1,0 instead of 'M' and 'B'
#  используйте 1,0 вместо 'M' и 'B'

# %%
#злокачественный как 0, а доброкачественный как 1
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B':0})
df.sample(5) #случайные строки
# Out:
#           diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 869254            0        10.75         14.97           68.26      355.3
# 922840            0        10.26         16.58           65.85      320.8
# 867387            0        15.71         13.93          102.00      761.7
# 88466802          0        10.65         25.22           68.01      347.0
# 884689            0        11.52         14.93           73.87      406.3
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 869254            0.07793           0.05139         0.02251
# 922840            0.08877           0.08066         0.04358
# 867387            0.09462           0.09462         0.07135
# 88466802          0.09657           0.07234         0.02379
# 884689            0.10130           0.07808         0.04328
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %% [markdown]
# ### 5、please split the data into training data and test data
#  разделите данные на обучающие данные и тестовые данные
# ##### тренировочный набор - набор для того, чтобы тренировать модель
# ##### тестовый набор - набор для того, чтобы тестировать модель

# %%
#X=df.drop('diagnosis',axis = 1)
#type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
#print(X_train, X_test, y_train, y_test)

# %% [markdown]
# ### 6、please do data preprocesing
# сделайте предварительную обработку данных

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_s = scaler.fit_transform(X_train)
x_test_s = scaler.fit_transform(X_test)

# %% [markdown]
# ### 7、please use SVM to do classification
# используйте SVM для классификации

# %%
from sklearn.svm import SVC
from sklearn import metrics
svclassifier = SVC(kernel='linear')
svclassifier.fit(x_train_s, y_train)
y_predict = svclassifier.predict(x_test_s)
print('Точность:' , metrics.accuracy_score(y_test, y_predict))
# Out:
# Точность: 0.0
